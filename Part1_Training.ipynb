# %%
from Utils.train_batched_A2C import *
from Utils.inspection_plots import *
from AC_modules.BatchedA2C import SpatialA2C
import AC_modules.Networks as net
import torch

from Env.test_env import Sandbox

# %%
RESOLUTION = 16
game_params = dict(res=RESOLUTION)

# %%
model_number = 1
model_names = {0:"Critic-semi-conv", 1:'shared-architecture'}

if model_number == 0:
    print(model_names[model_number]+" selected.")
    actor_model = net.SpatialNet
    critic_model = net.CriticNet
    actor_dict = {"in_channels":2, 'linear_size':RESOLUTION}
    critic_dict = {"in_channels":2, 'linear_size':RESOLUTION}
    
    HPs = dict(gamma=0.99, n_steps=5, H=1e-3, 
           actor_model=actor_model, critic_model=critic_model,
           actor_dict=actor_dict, critic_dict=critic_dict)
elif model_number == 1:
    print(model_names[model_number]+" selected.")
    n_channels = 32
    spatial_model = net.SharedNet
    spatial_dict = {'in_channels':2, 'n_channels':n_channels}
    shared_act_dict = {'n_channels':n_channels, 'linear_size':RESOLUTION}
    shared_crit_dict = {'n_channels':n_channels, 'linear_size':RESOLUTION}
    HPs = dict(gamma=0.99, n_steps=5, H=1e-3, shared=True,
               spatial_model=spatial_model, spatial_dict=spatial_dict, 
               shared_act_dict=shared_act_dict, shared_crit_dict=shared_crit_dict)
else:
    print("Model number not available. Choose 0.")
# Out:
# shared-architecture selected.

# %%
if torch.cuda.is_available():
    HPs['device'] = 'cuda'
else:
    HPs['device'] = 'cpu'
    
print("Using device "+HPs['device'])

lr = 1e-4
agent = SpatialA2C(**HPs)
# Out:
# Using device cuda

# %%
unroll_length = 240
MAX_STEPS = 250
train_dict = dict(n_train_processes = 11,
                  max_train_steps = unroll_length*5000,
                  unroll_length = unroll_length,
                  max_episode_steps = MAX_STEPS,
                  test_interval = unroll_length*10 
                  )

# %%
# %%time
results = train_batched_A2C(agent, game_params, lr, **train_dict)
# Out:
# Process ID:  FCSE
# Step # : 2400, avg score : 0.8
# Step # : 4800, avg score : 0.6
# Step # : 7200, avg score : 0.6
# Step # : 9600, avg score : 0.0
# Step # : 12000, avg score : 0.4
# Step # : 14400, avg score : 0.4
# Step # : 16800, avg score : 0.2
# Step # : 19200, avg score : 0.4
# Step # : 21600, avg score : 0.2
# Step # : 24000, avg score : 0.8
# Step # : 26400, avg score : 0.4
# Step # : 28800, avg score : 0.0
# Step # : 31200, avg score : 0.2
# Step # : 33600, avg score : 0.4
# Step # : 36000, avg score : 0.4
# Step # : 38400, avg score : 0.8
# Step # : 40800, avg score : 1.0
# Step # : 43200, avg score : 0.4
# Step # : 45600, avg score : 0.2
# Step # : 48000, avg score : 0.8
# Step # : 50400, avg score : 0.4
# Step # : 52800, avg score : 0.2
# Step # : 55200, avg score : 1.0
# Step # : 57600, avg score : 0.2
# Step # : 60000, avg score : 0.4
# Step # : 62400, avg score : 0.6
# Step # : 64800, avg score : 0.8
# Step # : 67200, avg score : 0.6
# Step # : 69600, avg score : 1.0
# Step # : 72000, avg score : 0.4
# Step # : 74400, avg score : 0.4
# Step # : 76800, avg score : 0.4
# Step # : 79200, avg score : 0.8
# Step # : 81600, avg score : 0.2
# Step # : 84000, avg score : 1.0
# Step # : 86400, avg score : 0.2
# Step # : 88800, avg score : 0.6
# Step # : 91200, avg score : 0.4
# Step # : 93600, avg score : 0.2
# Step # : 96000, avg score : 0.8
# Step # : 98400, avg score : 0.8
# Step # : 100800, avg score : 0.6
# Step # : 103200, avg score : 1.0
# Step # : 105600, avg score : 2.2
# Step # : 108000, avg score : 2.2
# Step # : 110400, avg score : 3.6
# Step # : 112800, avg score : 8.6
# Step # : 115200, avg score : 13.0
# Step # : 117600, avg score : 17.0
# Step # : 120000, avg score : 18.8
# Step # : 122400, avg score : 18.2
# Step # : 124800, avg score : 18.6
# Step # : 127200, avg score : 21.4
# Step # : 129600, avg score : 22.6
# Step # : 132000, avg score : 20.2
# Step # : 134400, avg score : 20.8
# Step # : 136800, avg score : 23.2
# Step # : 139200, avg score : 23.6
# Step # : 141600, avg score : 23.0
# Step # : 144000, avg score : 23.4
# Step # : 146400, avg score : 23.2
# Step # : 148800, avg score : 23.2
# Step # : 151200, avg score : 21.4
# Step # : 153600, avg score : 23.0
# Step # : 156000, avg score : 20.4
# Step # : 158400, avg score : 22.4
# Step # : 160800, avg score : 22.6
# Step # : 163200, avg score : 21.2
# Step # : 165600, avg score : 22.2
# Step # : 168000, avg score : 22.0
# Step # : 170400, avg score : 21.2
# Step # : 172800, avg score : 22.0
# Step # : 175200, avg score : 24.4
# Step # : 177600, avg score : 21.6
# Step # : 180000, avg score : 22.6
# Step # : 182400, avg score : 22.6
# Step # : 184800, avg score : 25.0
# Step # : 187200, avg score : 22.4
# Step # : 189600, avg score : 22.4
# Step # : 192000, avg score : 23.2
# Step # : 194400, avg score : 21.0
# Step # : 196800, avg score : 22.4
# Step # : 199200, avg score : 22.2
# Step # : 201600, avg score : 24.4
# Step # : 204000, avg score : 22.2
# Step # : 206400, avg score : 22.8
# Step # : 208800, avg score : 22.6
# Step # : 211200, avg score : 24.2
# Step # : 213600, avg score : 25.0
# Step # : 216000, avg score : 23.6
# Step # : 218400, avg score : 23.8
# Step # : 220800, avg score : 23.4
# Step # : 223200, avg score : 23.4
# Step # : 225600, avg score : 25.8
# Step # : 228000, avg score : 24.6
# Step # : 230400, avg score : 25.8
# Step # : 232800, avg score : 26.0
# Step # : 235200, avg score : 24.6
# Step # : 237600, avg score : 25.4
# Step # : 240000, avg score : 24.4
# Step # : 242400, avg score : 24.0
# Step # : 244800, avg score : 24.0
# Step # : 247200, avg score : 25.0
# Step # : 249600, avg score : 24.2
# Step # : 252000, avg score : 25.0
# Step # : 254400, avg score : 24.6
# Step # : 256800, avg score : 25.4
# Step # : 259200, avg score : 25.8
# Step # : 261600, avg score : 24.8
# Step # : 264000, avg score : 23.8
# Step # : 266400, avg score : 26.6
# Step # : 268800, avg score : 23.8
# Step # : 271200, avg score : 26.8
# Step # : 273600, avg score : 25.2
# Step # : 276000, avg score : 24.8
# Step # : 278400, avg score : 25.0
# Step # : 280800, avg score : 23.6
# Step # : 283200, avg score : 26.0
# Step # : 285600, avg score : 22.8
# Step # : 288000, avg score : 24.6
# Step # : 290400, avg score : 22.6
# Step # : 292800, avg score : 26.0
# Step # : 295200, avg score : 24.4
# Step # : 297600, avg score : 25.6
# Step # : 300000, avg score : 23.4
# Step # : 302400, avg score : 25.2
# Step # : 304800, avg score : 25.6
# Step # : 307200, avg score : 26.8
# Step # : 309600, avg score : 24.6
# Step # : 312000, avg score : 26.6
# Step # : 314400, avg score : 25.4
# Step # : 316800, avg score : 23.8
# Step # : 319200, avg score : 24.8
# Step # : 321600, avg score : 24.6
# Step # : 324000, avg score : 23.8
# Step # : 326400, avg score : 25.0
# Step # : 328800, avg score : 23.4
# Step # : 331200, avg score : 24.8
# Step # : 333600, avg score : 23.6
# Step # : 336000, avg score : 25.0
# Step # : 338400, avg score : 24.8
# Step # : 340800, avg score : 22.8
# Step # : 343200, avg score : 25.8
# Step # : 345600, avg score : 25.4
# Step # : 348000, avg score : 24.4
# Step # : 350400, avg score : 23.2
# Step # : 352800, avg score : 26.2
# Step # : 355200, avg score : 27.8
# Step # : 357600, avg score : 24.8
# Step # : 360000, avg score : 25.8
# Step # : 362400, avg score : 27.4
# Step # : 364800, avg score : 24.6
# Step # : 367200, avg score : 26.4
# Step # : 369600, avg score : 23.4
# Step # : 372000, avg score : 23.0
# Step # : 374400, avg score : 26.6
# Step # : 376800, avg score : 26.6
# Step # : 379200, avg score : 27.2
# Step # : 381600, avg score : 27.0
# Step # : 384000, avg score : 25.2
# Step # : 386400, avg score : 26.8
# Step # : 388800, avg score : 26.2
# Step # : 391200, avg score : 26.4
# Step # : 393600, avg score : 25.0
# Step # : 396000, avg score : 24.8
# Step # : 398400, avg score : 25.8
# Step # : 400800, avg score : 26.6
# Step # : 403200, avg score : 27.0
# Step # : 405600, avg score : 24.8
# Step # : 408000, avg score : 24.4
# Step # : 410400, avg score : 25.6
# Step # : 412800, avg score : 26.2
# Step # : 415200, avg score : 24.6
# Step # : 417600, avg score : 23.8
# Step # : 420000, avg score : 25.6
# Step # : 422400, avg score : 23.4
# Step # : 424800, avg score : 24.6
# Step # : 427200, avg score : 24.2
# Step # : 429600, avg score : 23.2
# Step # : 432000, avg score : 25.0
# Step # : 434400, avg score : 25.8
# Step # : 436800, avg score : 23.8
# Step # : 439200, avg score : 24.8
# Step # : 441600, avg score : 26.8
# Step # : 444000, avg score : 25.4
# Step # : 446400, avg score : 24.2
# Step # : 448800, avg score : 24.8
# Step # : 451200, avg score : 25.6
# Step # : 453600, avg score : 25.4
# Step # : 456000, avg score : 26.2
# Step # : 458400, avg score : 25.2
# Step # : 460800, avg score : 24.8
# Step # : 463200, avg score : 25.4
# Step # : 465600, avg score : 26.8
# Step # : 468000, avg score : 24.6
# Step # : 470400, avg score : 24.0
# Step # : 472800, avg score : 24.8
# Step # : 475200, avg score : 24.2
# Step # : 477600, avg score : 25.8
# Step # : 480000, avg score : 26.2
# Step # : 482400, avg score : 26.0
# Step # : 484800, avg score : 25.0
# Step # : 487200, avg score : 26.8
# Step # : 489600, avg score : 25.0
# Step # : 492000, avg score : 23.8
# Step # : 494400, avg score : 25.6
# Step # : 496800, avg score : 25.2
# Step # : 499200, avg score : 25.2
# Step # : 501600, avg score : 27.2
# Step # : 504000, avg score : 26.0
# Step # : 506400, avg score : 22.6
# Step # : 508800, avg score : 27.0
# Step # : 511200, avg score : 25.8
# Step # : 513600, avg score : 25.8
# Step # : 516000, avg score : 24.8
# Step # : 518400, avg score : 24.2
# Step # : 520800, avg score : 25.6
# Step # : 523200, avg score : 24.2
# Step # : 525600, avg score : 25.2
# Step # : 528000, avg score : 24.0
# Step # : 530400, avg score : 26.0
# Step # : 532800, avg score : 25.4
# Step # : 535200, avg score : 26.4
# Step # : 537600, avg score : 25.0
# Step # : 540000, avg score : 25.0
# Step # : 542400, avg score : 25.6
# Step # : 544800, avg score : 25.2
# Step # : 547200, avg score : 24.2
# Step # : 549600, avg score : 24.0
# Step # : 552000, avg score : 26.4
# Step # : 554400, avg score : 24.0
# Step # : 556800, avg score : 26.0
# Step # : 559200, avg score : 24.4
# Step # : 561600, avg score : 25.0
# Step # : 564000, avg score : 25.4
# Step # : 566400, avg score : 24.8
# Step # : 568800, avg score : 26.0
# Step # : 571200, avg score : 27.4
# Step # : 573600, avg score : 26.6
# Step # : 576000, avg score : 24.8
# Step # : 578400, avg score : 24.4
# Step # : 580800, avg score : 27.0
# Step # : 583200, avg score : 23.6
# Step # : 585600, avg score : 25.4
# Step # : 588000, avg score : 26.0
# Step # : 590400, avg score : 27.6
# Step # : 592800, avg score : 25.6
# Step # : 595200, avg score : 25.4
# Step # : 597600, avg score : 25.4
# Step # : 600000, avg score : 25.0
# Step # : 602400, avg score : 26.0
# Step # : 604800, avg score : 24.8
# Step # : 607200, avg score : 25.4
# Step # : 609600, avg score : 25.0
# Step # : 612000, avg score : 27.6
# Step # : 614400, avg score : 23.8
# Step # : 616800, avg score : 26.4
# Step # : 619200, avg score : 26.2
# Step # : 621600, avg score : 25.8
# Step # : 624000, avg score : 25.0
# Step # : 626400, avg score : 23.0
# Step # : 628800, avg score : 26.0
# Step # : 631200, avg score : 24.4
# Step # : 633600, avg score : 27.2
# Step # : 636000, avg score : 25.8
# Step # : 638400, avg score : 25.0
# Step # : 640800, avg score : 24.6
# Step # : 643200, avg score : 23.4
# Step # : 645600, avg score : 26.0
# Step # : 648000, avg score : 23.8
# Step # : 650400, avg score : 26.0
# Step # : 652800, avg score : 25.6
# Step # : 655200, avg score : 24.0
# Step # : 657600, avg score : 24.4
# Step # : 660000, avg score : 25.0
# Step # : 662400, avg score : 26.0
# Step # : 664800, avg score : 25.6
# Step # : 667200, avg score : 26.6
# Step # : 669600, avg score : 25.0
# Step # : 672000, avg score : 24.6
# Step # : 674400, avg score : 27.0
# Step # : 676800, avg score : 26.8
# Step # : 679200, avg score : 27.6
# Step # : 681600, avg score : 25.4
# Step # : 684000, avg score : 26.6
# Step # : 686400, avg score : 25.4
# Step # : 688800, avg score : 24.2
# Step # : 691200, avg score : 23.8
# Step # : 693600, avg score : 25.4
# Step # : 696000, avg score : 25.6
# Step # : 698400, avg score : 25.4
# Step # : 700800, avg score : 25.2
# Step # : 703200, avg score : 23.0
# Step # : 705600, avg score : 29.4
# Step # : 708000, avg score : 24.6
# Step # : 710400, avg score : 24.4
# Step # : 712800, avg score : 29.0
# Step # : 715200, avg score : 28.8
# Step # : 717600, avg score : 26.4
# Step # : 720000, avg score : 26.4
# Step # : 722400, avg score : 26.2
# Step # : 724800, avg score : 24.4
# Step # : 727200, avg score : 23.6
# Step # : 729600, avg score : 25.8
# Step # : 732000, avg score : 27.8
# Step # : 734400, avg score : 26.2
# Step # : 736800, avg score : 23.4
# Step # : 739200, avg score : 28.0
# Step # : 741600, avg score : 26.2
# Step # : 744000, avg score : 26.0
# Step # : 746400, avg score : 24.2
# Step # : 748800, avg score : 25.6
# Step # : 751200, avg score : 26.8
# Step # : 753600, avg score : 24.0
# Step # : 756000, avg score : 25.6
# Step # : 758400, avg score : 25.4
# Step # : 760800, avg score : 26.8
# Step # : 763200, avg score : 27.6
# Step # : 765600, avg score : 25.8
# Step # : 768000, avg score : 25.0
# Step # : 770400, avg score : 25.2
# Step # : 772800, avg score : 26.8
# Step # : 775200, avg score : 26.6
# Step # : 777600, avg score : 27.0
# Step # : 780000, avg score : 25.6
# Step # : 782400, avg score : 25.6
# Step # : 784800, avg score : 26.0
# Step # : 787200, avg score : 28.8
# Step # : 789600, avg score : 24.8
# Step # : 792000, avg score : 26.2
# Step # : 794400, avg score : 24.4
# Step # : 796800, avg score : 24.8
# Step # : 799200, avg score : 27.2
# Step # : 801600, avg score : 26.4
# Step # : 804000, avg score : 26.6
# Step # : 806400, avg score : 26.0
# Step # : 808800, avg score : 24.4
# Step # : 811200, avg score : 24.8
# Step # : 813600, avg score : 25.2
# Step # : 816000, avg score : 25.6
# Step # : 818400, avg score : 26.8
# Step # : 820800, avg score : 25.0
# Step # : 823200, avg score : 26.0
# Step # : 825600, avg score : 27.6
# Step # : 828000, avg score : 25.6
# Step # : 830400, avg score : 24.6
# Step # : 832800, avg score : 27.6
# Step # : 835200, avg score : 25.2
# Step # : 837600, avg score : 25.4
# Step # : 840000, avg score : 24.6
# Step # : 842400, avg score : 27.2
# Step # : 844800, avg score : 27.2
# Step # : 847200, avg score : 23.2
# Step # : 849600, avg score : 25.4
# Step # : 852000, avg score : 25.8
# Step # : 854400, avg score : 26.0
# Step # : 856800, avg score : 25.8
# Step # : 859200, avg score : 25.4
# Step # : 861600, avg score : 26.4
# Step # : 864000, avg score : 25.2
# Step # : 866400, avg score : 25.2
# Step # : 868800, avg score : 24.6
# Step # : 871200, avg score : 25.4
# Step # : 873600, avg score : 26.6
# Step # : 876000, avg score : 26.6
# Step # : 878400, avg score : 25.0
# Step # : 880800, avg score : 26.4
# Step # : 883200, avg score : 25.4
# Step # : 885600, avg score : 26.0
# Step # : 888000, avg score : 25.4
# Step # : 890400, avg score : 25.0
# Step # : 892800, avg score : 26.2
# Step # : 895200, avg score : 26.8
# Step # : 897600, avg score : 27.0
# Step # : 900000, avg score : 25.6
# Step # : 902400, avg score : 27.8
# Step # : 904800, avg score : 25.6
# Step # : 907200, avg score : 25.0
# Step # : 909600, avg score : 24.6
# Step # : 912000, avg score : 25.6
# Step # : 914400, avg score : 26.2
# Step # : 916800, avg score : 24.8
# Step # : 919200, avg score : 24.0
# Step # : 921600, avg score : 24.2
# Step # : 924000, avg score : 24.0
# Step # : 926400, avg score : 24.8
# Step # : 928800, avg score : 24.0
# Step # : 931200, avg score : 24.8
# Step # : 933600, avg score : 26.8
# Step # : 936000, avg score : 29.0
# Step # : 938400, avg score : 26.4
# Step # : 940800, avg score : 27.2
# Step # : 943200, avg score : 27.0
# Step # : 945600, avg score : 26.6
# Step # : 948000, avg score : 25.6
# Step # : 950400, avg score : 25.2
# Step # : 952800, avg score : 25.8
# Step # : 955200, avg score : 25.6
# Step # : 957600, avg score : 24.4
# Step # : 960000, avg score : 25.4
# Step # : 962400, avg score : 25.4
# Step # : 964800, avg score : 26.2
# Step # : 967200, avg score : 25.2
# Step # : 969600, avg score : 24.6
# Step # : 972000, avg score : 24.0
# Step # : 974400, avg score : 26.4
# Step # : 976800, avg score : 25.4
# Step # : 979200, avg score : 26.2
# Step # : 981600, avg score : 23.6
# Step # : 984000, avg score : 25.4
# Step # : 986400, avg score : 25.6
# Step # : 988800, avg score : 25.2
# Step # : 991200, avg score : 26.0
# Step # : 993600, avg score : 24.8
# Step # : 996000, avg score : 26.8
# Step # : 998400, avg score : 24.0
# Step # : 1000800, avg score : 24.0
# Step # : 1003200, avg score : 26.0
# Step # : 1005600, avg score : 27.4
# Step # : 1008000, avg score : 22.8
# Step # : 1010400, avg score : 27.6
# Step # : 1012800, avg score : 26.0
# Step # : 1015200, avg score : 26.0
# Step # : 1017600, avg score : 24.8
# Step # : 1020000, avg score : 25.6
# Step # : 1022400, avg score : 25.0
# Step # : 1024800, avg score : 25.2
# Step # : 1027200, avg score : 26.6
# Step # : 1029600, avg score : 23.4
# Step # : 1032000, avg score : 26.0
# Step # : 1034400, avg score : 24.2
# Step # : 1036800, avg score : 25.0
# Step # : 1039200, avg score : 27.0
# Step # : 1041600, avg score : 26.6
# Step # : 1044000, avg score : 27.0
# Step # : 1046400, avg score : 26.0
# Step # : 1048800, avg score : 27.6
# Step # : 1051200, avg score : 26.0
# Step # : 1053600, avg score : 26.2
# Step # : 1056000, avg score : 24.6
# Step # : 1058400, avg score : 25.0
# Step # : 1060800, avg score : 25.8
# Step # : 1063200, avg score : 25.4
# Step # : 1065600, avg score : 26.2
# Step # : 1068000, avg score : 24.8
# Step # : 1070400, avg score : 26.8
# Step # : 1072800, avg score : 26.2
# Step # : 1075200, avg score : 24.4
# Step # : 1077600, avg score : 27.2
# Step # : 1080000, avg score : 24.8
# Step # : 1082400, avg score : 24.4
# Step # : 1084800, avg score : 26.0
# Step # : 1087200, avg score : 24.2
# Step # : 1089600, avg score : 24.6
# Step # : 1092000, avg score : 23.2
# Step # : 1094400, avg score : 26.2
# Step # : 1096800, avg score : 26.0
# Step # : 1099200, avg score : 25.0
# Step # : 1101600, avg score : 27.6
# Step # : 1104000, avg score : 25.8
# Step # : 1106400, avg score : 25.2
# Step # : 1108800, avg score : 24.8
# Step # : 1111200, avg score : 28.2
# Step # : 1113600, avg score : 25.2
# Step # : 1116000, avg score : 24.8
# Step # : 1118400, avg score : 27.6
# Step # : 1120800, avg score : 23.6
# Step # : 1123200, avg score : 24.8
# Step # : 1125600, avg score : 26.4
# Step # : 1128000, avg score : 28.8
# Step # : 1130400, avg score : 24.6
# Step # : 1132800, avg score : 27.0
# Step # : 1135200, avg score : 26.4
# Step # : 1137600, avg score : 22.4
# Step # : 1140000, avg score : 25.8
# Step # : 1142400, avg score : 25.0
# Step # : 1144800, avg score : 23.8
# Step # : 1147200, avg score : 24.8
# Step # : 1149600, avg score : 23.2
# Step # : 1152000, avg score : 26.2
# Step # : 1154400, avg score : 25.4
# Step # : 1156800, avg score : 25.8
# Step # : 1159200, avg score : 25.4
# Step # : 1161600, avg score : 25.6
# Step # : 1164000, avg score : 26.4
# Step # : 1166400, avg score : 26.4
# Step # : 1168800, avg score : 24.4
# Step # : 1171200, avg score : 27.2
# Step # : 1173600, avg score : 26.4
# Step # : 1176000, avg score : 27.2
# Step # : 1178400, avg score : 27.0
# Step # : 1180800, avg score : 26.6
# Step # : 1183200, avg score : 24.2
# Step # : 1185600, avg score : 24.2
# Step # : 1188000, avg score : 25.0
# Step # : 1190400, avg score : 25.0
# Step # : 1192800, avg score : 27.2
# Step # : 1195200, avg score : 28.4
# Step # : 1197600, avg score : 22.6
# Step # : 1200000, avg score : 24.0
# CPU times: user 3h 14min 50s, sys: 5min 54s, total: 3h 20min 44s
# Wall time: 1h 16min 23s

# %%
score, losses, trained_agent, PID = results

# %%
#from Utils import utils
save = True
keywords = ["shared",'lr-1e-4','5-steps',"1.2M-env-steps","240-unroll-len",'working!'] 

if save:
    save_dir = 'Results/'
    keywords.append(PID)
    filename = '_'.join(keywords)
    filename = 'S_'+filename
    print("Save at "+save_dir+filename)
    train_session_dict = dict(game_params=game_params, HPs=HPs, score=score, n_epochs=len(score), keywords=keywords, losses=losses)
    np.save(save_dir+filename, train_session_dict)
    torch.save(trained_agent, save_dir+"agent_"+PID)
else:
    print("Nothing saved")
    pass
# Out:
# Save at Results/S_shared_lr-1e-4_5-steps_1.2M-env-steps_240-unroll-len_working!_FCSE
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedSpatialActorCritic. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedActor. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedActorNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedCritic. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedCriticNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
step_idx = 0
test_env = Sandbox(max_steps=MAX_STEPS, **game_params)
PID = 'prova'
R, insp = inspection_test(step_idx, agent, test_env, PID)
insp_dict = insp.dict
for t in range(len(insp_dict['state_traj'])):
    plot_state(insp_dict, t)
    plt.show()
